# %% [markdown]
# ## Random forest
# Test pour l'anglais.

# %%
# importing modules
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# load data
df = pd.read_csv("../data/extracted_data_en.csv")
data = pd.read_csv("../data/vectorized_data_en.csv")

# %%
data['cat_id'] = df['Party'] # adding labels to vectorized texts
train, test = train_test_split(data, test_size=0.2, 
                               train_size=0.8, shuffle=True)

# %%
x_train, y_train_label = train.loc[:, "0":"19"], train["cat_id"].values.astype(object)
x_test, y_test_label = test.loc[:, "0":"19"], test["cat_id"].values.astype(object)

# %%
y_train_label
# Out:
# array(['ELDR', 'PSE', 'PPE-DE', ..., 'Verts-ALE', 'PPE-DE', 'PSE'],
#       dtype=object)

# %%
print(np.unique(y_train_label)) # 5 parties
# Out:
# ['ELDR' 'GUE-NGL' 'PPE-DE' 'PSE' 'Verts-ALE']

# %%
# encoding string labels as numerical labels
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
# encoding train labels
encoder.fit(y_train_label)
y_train = encoder.transform(y_train_label)
# encoding test labels
encoder.fit(y_test_label)
y_test = encoder.transform(y_test_label)
print(y_train)
# Out:
# [0 3 2 ... 4 2 3]

# %% [markdown]
# > **Feature scaling**: standardize independent features present in the data in a fixed range. used to handle highly varying magnitudes/values/units... important if we want all features to be on a *comparable scale* and have *comparable ranges*.

# %% [markdown]
# Plus d'infos [ici](https://www.geeksforgeeks.org/ml-feature-scaling-part-2/) et [ici aussi](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# standardization of the data
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
# grid search
from sklearn.model_selection import cross_val_score, GridSearchCV
n_estimators = [20, 25]
max_depth = [15, 25, 30]
criterion = ["gini"]
min_samples_leaf = [2, 3]
bootstrap = [True]
max_samples = [500, 1000, 5000, 7000]

param_grid = {
    "n_estimators" : n_estimators,
    "max_depth" : max_depth,
    "min_samples_leaf" : min_samples_leaf,
    "bootstrap" : bootstrap,
    "max_samples" : max_samples,
    "criterion" : criterion
}

rf = RandomForestClassifier(random_state=42)
rf_model = GridSearchCV(estimator=rf, param_grid=param_grid,
                        verbose=10, n_jobs=1)
rf_model.fit(x_train_scaled, y_train)

print("Using hyperparameters --> \n", rf_model.best_params_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 1/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.334 total time=   0.2s
# [CV 2/5; 1/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 1/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 3/5; 1/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 1/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 4/5; 1/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 1/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.335 total time=   0.2s
# [CV 5/5; 1/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 1/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.334 total time=   0.2s
# [CV 1/5; 2/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 2/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.338 total time=   0.3s
# [CV 2/5; 2/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 2/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.341 total time=   0.2s
# [CV 3/5; 2/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 2/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.342 total time=   0.3s
# [CV 4/5; 2/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 2/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.342 total time=   0.2s
# [CV 5/5; 2/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 2/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.330 total time=   0.3s
# [CV 1/5; 3/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 3/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 2/5; 3/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 3/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 3/5; 3/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 3/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.341 total time=   0.2s
# [CV 4/5; 3/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 3/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.355 total time=   0.2s
# [CV 5/5; 3/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 3/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.352 total time=   0.2s
# [CV 1/5; 4/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 4/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.348 total time=   0.3s
# [CV 2/5; 4/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 4/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.348 total time=   0.3s
# [CV 3/5; 4/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 4/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.344 total time=   0.3s
# [CV 4/5; 4/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 4/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.366 total time=   0.3s
# [CV 5/5; 4/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 4/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.352 total time=   0.2s
# [CV 1/5; 5/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 5/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.343 total time=   0.3s
# [CV 2/5; 5/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 5/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.338 total time=   0.3s
# [CV 3/5; 5/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 5/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.341 total time=   0.3s
# [CV 4/5; 5/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 5/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   0.3s
# [CV 5/5; 5/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 5/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.344 total time=   0.3s
# [CV 1/5; 6/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 6/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.354 total time=   0.4s
# [CV 2/5; 6/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 6/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.346 total time=   0.4s
# [CV 3/5; 6/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 6/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.352 total time=   0.4s
# [CV 4/5; 6/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 6/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.356 total time=   0.4s
# [CV 5/5; 6/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 6/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.344 total time=   0.4s
# [CV 1/5; 7/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 7/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   0.3s
# [CV 2/5; 7/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 7/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.344 total time=   0.3s
# [CV 3/5; 7/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 7/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.345 total time=   0.3s
# [CV 4/5; 7/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 7/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.345 total time=   0.3s
# [CV 5/5; 7/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 7/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.341 total time=   0.3s
# [CV 1/5; 8/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 8/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.355 total time=   0.4s
# [CV 2/5; 8/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 8/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.355 total time=   0.4s
# [CV 3/5; 8/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 8/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.346 total time=   0.4s
# [CV 4/5; 8/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 8/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.346 total time=   0.4s
# [CV 5/5; 8/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 8/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.337 total time=   0.4s
# [CV 1/5; 9/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 9/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.358 total time=   1.1s
# [CV 2/5; 9/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 9/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.348 total time=   1.2s
# [CV 3/5; 9/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 9/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.343 total time=   1.1s
# [CV 4/5; 9/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 9/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.352 total time=   1.1s
# [CV 5/5; 9/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 9/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.336 total time=   1.1s
# [CV 1/5; 10/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 10/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.362 total time=   1.4s
# [CV 2/5; 10/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 10/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.346 total time=   1.4s
# [CV 3/5; 10/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 10/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.349 total time=   1.4s
# [CV 4/5; 10/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 10/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.355 total time=   1.4s
# [CV 5/5; 10/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 10/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.342 total time=   1.4s
# [CV 1/5; 11/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 11/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.354 total time=   1.1s
# [CV 2/5; 11/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 11/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   1.1s
# [CV 3/5; 11/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 11/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.351 total time=   1.1s
# [CV 4/5; 11/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 11/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.355 total time=   1.1s
# [CV 5/5; 11/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 11/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.350 total time=   1.1s
# [CV 1/5; 12/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 12/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.355 total time=   1.3s
# [CV 2/5; 12/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 12/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.344 total time=   1.3s
# [CV 3/5; 12/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 12/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.355 total time=   1.3s
# [CV 4/5; 12/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 12/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.356 total time=   1.4s
# [CV 5/5; 12/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 12/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.345 total time=   1.3s
# [CV 1/5; 13/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 13/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.353 total time=   1.4s
# [CV 2/5; 13/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 13/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.351 total time=   1.4s
# [CV 3/5; 13/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 13/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.334 total time=   1.5s
# [CV 4/5; 13/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 13/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.359 total time=   1.4s
# [CV 5/5; 13/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 13/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   1.4s
# [CV 1/5; 14/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 14/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.360 total time=   1.9s
# [CV 2/5; 14/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 14/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.350 total time=   2.0s
# [CV 3/5; 14/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 14/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   1.9s
# [CV 4/5; 14/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 14/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.358 total time=   2.0s
# [CV 5/5; 14/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 14/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.349 total time=   1.7s
# [CV 1/5; 15/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 15/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.359 total time=   1.4s
# [CV 2/5; 15/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 15/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.342 total time=   1.4s
# [CV 3/5; 15/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 15/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.339 total time=   1.4s
# [CV 4/5; 15/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 15/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.345 total time=   1.4s
# [CV 5/5; 15/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 15/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.346 total time=   1.4s
# [CV 1/5; 16/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 16/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.369 total time=   1.8s
# [CV 2/5; 16/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 16/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.351 total time=   1.8s
# [CV 3/5; 16/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 16/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.344 total time=   1.7s
# [CV 4/5; 16/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 16/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.354 total time=   1.7s
# [CV 5/5; 16/48] START bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 16/48] END bootstrap=True, criterion=gini, max_depth=15, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.349 total time=   1.7s
# [CV 1/5; 17/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 17/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   0.2s
# [CV 2/5; 17/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 17/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 3/5; 17/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 17/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.329 total time=   0.2s
# [CV 4/5; 17/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 17/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.333 total time=   0.2s
# [CV 5/5; 17/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 17/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.327 total time=   0.2s
# [CV 1/5; 18/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 18/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.351 total time=   0.2s
# [CV 2/5; 18/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 18/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.348 total time=   0.3s
# [CV 3/5; 18/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 18/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.335 total time=   0.2s
# [CV 4/5; 18/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 18/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.339 total time=   0.2s
# [CV 5/5; 18/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 18/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.335 total time=   0.2s
# [CV 1/5; 19/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 19/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.350 total time=   0.2s
# [CV 2/5; 19/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 19/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.344 total time=   0.2s
# [CV 3/5; 19/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 19/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.338 total time=   0.2s
# [CV 4/5; 19/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 19/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.346 total time=   0.2s
# [CV 5/5; 19/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 19/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.353 total time=   0.2s
# [CV 1/5; 20/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 20/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.352 total time=   0.2s
# [CV 2/5; 20/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 20/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.356 total time=   0.2s
# [CV 3/5; 20/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 20/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.350 total time=   0.2s
# [CV 4/5; 20/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 20/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.353 total time=   0.2s
# [CV 5/5; 20/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 20/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=500, min_samples_leaf=3, n_estimators=25;, score=0.347 total time=   0.2s
# [CV 1/5; 21/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 21/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   0.3s
# [CV 2/5; 21/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 21/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.343 total time=   0.3s
# [CV 3/5; 21/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 21/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   0.3s
# [CV 4/5; 21/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 21/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.346 total time=   0.3s
# [CV 5/5; 21/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 21/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.3s
# [CV 1/5; 22/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 22/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.353 total time=   0.4s
# [CV 2/5; 22/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 22/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.355 total time=   0.4s
# [CV 3/5; 22/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 22/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   0.4s
# [CV 4/5; 22/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 22/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.350 total time=   0.5s
# [CV 5/5; 22/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 22/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   0.4s
# [CV 1/5; 23/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 23/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   0.3s
# [CV 2/5; 23/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 23/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.349 total time=   0.3s
# [CV 3/5; 23/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 23/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.344 total time=   0.3s
# [CV 4/5; 23/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 23/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.348 total time=   0.3s
# [CV 5/5; 23/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 23/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.343 total time=   0.3s
# [CV 1/5; 24/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 24/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.351 total time=   0.4s
# [CV 2/5; 24/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 24/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.353 total time=   0.4s
# [CV 3/5; 24/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 24/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.357 total time=   0.4s
# [CV 4/5; 24/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 24/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.345 total time=   0.4s
# [CV 5/5; 24/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 24/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.349 total time=   0.4s
# [CV 1/5; 25/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 25/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   1.3s
# [CV 2/5; 25/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 25/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.343 total time=   1.3s
# [CV 3/5; 25/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 25/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.327 total time=   1.2s
# [CV 4/5; 25/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 25/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.333 total time=   1.2s
# [CV 5/5; 25/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 25/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.344 total time=   1.2s
# [CV 1/5; 26/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 26/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.366 total time=   1.5s
# [CV 2/5; 26/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 26/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.341 total time=   1.5s
# [CV 3/5; 26/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 26/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.334 total time=   1.5s
# [CV 4/5; 26/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 26/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.345 total time=   1.5s
# [CV 5/5; 26/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 26/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   1.5s
# [CV 1/5; 27/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 27/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.354 total time=   1.2s
# [CV 2/5; 27/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 27/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.348 total time=   1.1s
# [CV 3/5; 27/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 27/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.348 total time=   1.2s
# [CV 4/5; 27/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 27/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   1.2s
# [CV 5/5; 27/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 27/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.336 total time=   1.1s
# [CV 1/5; 28/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 28/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.368 total time=   1.4s
# [CV 2/5; 28/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 28/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.346 total time=   1.5s
# [CV 3/5; 28/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 28/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.348 total time=   1.5s
# [CV 4/5; 28/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 28/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.352 total time=   1.4s
# [CV 5/5; 28/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 28/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.341 total time=   1.4s
# [CV 1/5; 29/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 29/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.343 total time=   1.6s
# [CV 2/5; 29/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 29/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.348 total time=   1.6s
# [CV 3/5; 29/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 29/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.338 total time=   1.6s
# [CV 4/5; 29/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 29/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.358 total time=   1.6s
# [CV 5/5; 29/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 29/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.346 total time=   1.6s
# [CV 1/5; 30/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 30/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.346 total time=   2.0s
# [CV 2/5; 30/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 30/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.350 total time=   2.0s
# [CV 3/5; 30/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 30/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.338 total time=   2.0s
# [CV 4/5; 30/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 30/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.368 total time=   2.0s
# [CV 5/5; 30/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 30/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.348 total time=   2.0s
# [CV 1/5; 31/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 31/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.357 total time=   1.5s
# [CV 2/5; 31/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 31/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.340 total time=   1.5s
# [CV 3/5; 31/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 31/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.348 total time=   1.6s
# [CV 4/5; 31/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 31/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.339 total time=   1.5s
# [CV 5/5; 31/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 31/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.339 total time=   1.5s
# [CV 1/5; 32/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 32/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.358 total time=   1.9s
# [CV 2/5; 32/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 32/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.343 total time=   1.9s
# [CV 3/5; 32/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 32/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.353 total time=   1.9s
# [CV 4/5; 32/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 32/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.350 total time=   1.9s
# [CV 5/5; 32/48] START bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 32/48] END bootstrap=True, criterion=gini, max_depth=25, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.350 total time=   1.9s
# [CV 1/5; 33/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 33/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.350 total time=   0.2s
# [CV 2/5; 33/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 33/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.2s
# [CV 3/5; 33/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 33/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.329 total time=   0.2s
# [CV 4/5; 33/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 33/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.333 total time=   0.2s
# [CV 5/5; 33/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 33/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=20;, score=0.327 total time=   0.2s
# [CV 1/5; 34/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 34/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.351 total time=   0.2s
# [CV 2/5; 34/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 34/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.348 total time=   0.2s
# [CV 3/5; 34/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 34/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.335 total time=   0.3s
# [CV 4/5; 34/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 34/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.339 total time=   0.2s
# [CV 5/5; 34/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 34/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=2, n_estimators=25;, score=0.339 total time=   0.2s
# [CV 1/5; 35/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 35/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.350 total time=   0.2s
# [CV 2/5; 35/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 35/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.344 total time=   0.2s
# [CV 3/5; 35/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 35/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.338 total time=   0.2s
# [CV 4/5; 35/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 35/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.346 total time=   0.2s
# [CV 5/5; 35/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 35/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=500, min_samples_leaf=3, n_estimators=20;, score=0.353 total time=   0.2s
# ...
# [CV 3/5; 37/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.352 total time=   0.3s
# [CV 4/5; 37/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 37/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.344 total time=   0.3s
# [CV 5/5; 37/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 37/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   0.3s
# [CV 1/5; 38/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 38/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.358 total time=   0.4s
# [CV 2/5; 38/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 38/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.355 total time=   0.4s
# [CV 3/5; 38/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 38/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   0.4s
# [CV 4/5; 38/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 38/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.349 total time=   0.4s
# [CV 5/5; 38/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 38/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=2, n_estimators=25;, score=0.347 total time=   0.4s
# [CV 1/5; 39/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 39/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.349 total time=   0.3s
# [CV 2/5; 39/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 39/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   0.3s
# [CV 3/5; 39/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 39/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.344 total time=   0.3s
# [CV 4/5; 39/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 39/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   0.3s
# [CV 5/5; 39/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 39/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=20;, score=0.343 total time=   0.3s
# [CV 1/5; 40/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 40/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.351 total time=   0.4s
# [CV 2/5; 40/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 40/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.354 total time=   0.4s
# [CV 3/5; 40/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 40/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.357 total time=   0.4s
# [CV 4/5; 40/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 40/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.345 total time=   0.4s
# [CV 5/5; 40/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 40/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=1000, min_samples_leaf=3, n_estimators=25;, score=0.346 total time=   0.4s
# [CV 1/5; 41/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 41/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.352 total time=   1.2s
# [CV 2/5; 41/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 41/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.336 total time=   1.3s
# [CV 3/5; 41/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 41/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.340 total time=   1.2s
# [CV 4/5; 41/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 41/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.337 total time=   1.2s
# [CV 5/5; 41/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 41/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=20;, score=0.336 total time=   1.2s
# [CV 1/5; 42/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 42/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.363 total time=   1.5s
# [CV 2/5; 42/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 42/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.343 total time=   1.5s
# [CV 3/5; 42/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 42/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.346 total time=   1.5s
# [CV 4/5; 42/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 42/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.341 total time=   1.5s
# [CV 5/5; 42/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 42/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=2, n_estimators=25;, score=0.342 total time=   1.5s
# [CV 1/5; 43/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 43/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.364 total time=   1.2s
# [CV 2/5; 43/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 43/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.336 total time=   1.2s
# [CV 3/5; 43/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 43/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.347 total time=   1.1s
# [CV 4/5; 43/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 43/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.339 total time=   1.2s
# [CV 5/5; 43/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 43/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=20;, score=0.337 total time=   1.1s
# [CV 1/5; 44/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 44/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.362 total time=   1.5s
# [CV 2/5; 44/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 44/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.337 total time=   1.5s
# [CV 3/5; 44/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 44/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.353 total time=   1.5s
# [CV 4/5; 44/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 44/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.352 total time=   1.5s
# [CV 5/5; 44/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 44/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=5000, min_samples_leaf=3, n_estimators=25;, score=0.345 total time=   1.4s
# [CV 1/5; 45/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 1/5; 45/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.351 total time=   1.6s
# [CV 2/5; 45/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 2/5; 45/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.351 total time=   1.6s
# [CV 3/5; 45/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 3/5; 45/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.336 total time=   1.6s
# [CV 4/5; 45/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 4/5; 45/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.338 total time=   1.6s
# [CV 5/5; 45/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20
# [CV 5/5; 45/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=20;, score=0.342 total time=   1.6s
# [CV 1/5; 46/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 1/5; 46/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.353 total time=   2.0s
# [CV 2/5; 46/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 2/5; 46/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.360 total time=   2.0s
# [CV 3/5; 46/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 3/5; 46/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.346 total time=   2.0s
# [CV 4/5; 46/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 4/5; 46/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.345 total time=   2.0s
# [CV 5/5; 46/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25
# [CV 5/5; 46/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=2, n_estimators=25;, score=0.353 total time=   2.0s
# [CV 1/5; 47/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 1/5; 47/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.346 total time=   1.5s
# [CV 2/5; 47/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 2/5; 47/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.334 total time=   1.5s
# [CV 3/5; 47/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 3/5; 47/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.338 total time=   1.6s
# [CV 4/5; 47/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 4/5; 47/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.346 total time=   1.7s
# [CV 5/5; 47/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20
# [CV 5/5; 47/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=20;, score=0.337 total time=   1.7s
# [CV 1/5; 48/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 1/5; 48/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.358 total time=   2.0s
# [CV 2/5; 48/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 2/5; 48/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.336 total time=   2.0s
# [CV 3/5; 48/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 3/5; 48/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.340 total time=   2.0s
# [CV 4/5; 48/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 4/5; 48/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.356 total time=   2.0s
# [CV 5/5; 48/48] START bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25
# [CV 5/5; 48/48] END bootstrap=True, criterion=gini, max_depth=30, max_samples=7000, min_samples_leaf=3, n_estimators=25;, score=0.349 total time=   2.0s
# Using hyperparameters -->
#  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 15, 'max_samples': 7000, 'min_samples_leaf': 3, 'n_estimators': 25}

# %%
print(rf_model.best_params_)
print(rf_model.best_score_)
print(rf_model.best_estimator_)
# Out:
# {'bootstrap': True, 'criterion': 'gini', 'max_depth': 15, 'max_samples': 7000, 'min_samples_leaf': 3, 'n_estimators': 25}
# 0.3532752500806712
# RandomForestClassifier(max_depth=15, max_samples=7000, min_samples_leaf=3,
#                        n_estimators=25, random_state=42)

# %%
y_pred = rf_model.predict(x_test_scaled)
y_pred_label = list(encoder.inverse_transform(y_pred))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
labels = ['ELDR', 'GUE-NGL', 'PPE-DE','PSE','Verts-ALE']
ax = plt.subplot()
cm = confusion_matrix(y_test_label, y_pred_label)
sns.heatmap(cm, annot=True, fmt='g', ax=ax, xticklabels=labels, yticklabels=labels)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix for english')
#sns.heatmap(cm, annot=True).set(title="Matrice de confusion")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for english')
